# %% [markdown]
# <a href="https://colab.research.google.com/github/sisiho/IBM-Data-Science-Peer-graded-assignments/blob/main/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# | No. | Word              | Definition                                                                                                    | Example                                                                                                                |
# |-----|-------------------|--------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------|
# | 1   | Didactic          | Intended to teach or instruct; educational or informative                                                    | The professor's lectures were didactic, providing valuable knowledge to the students.                                 |
# | 2   | Spurious          | False or deceitful; not genuine or authentic                                                                 | The article made spurious claims that were not supported by any evidence.                                               |
# | 3   | Inhibit           | To hinder, restrain, or prevent the progress or action of something                                          | Stage fright can inhibit a performer's ability to give a confident presentation.                                       |
# | 4   | Embryo            | An early stage of development; a rudimentary form of something                                               | The embryo grows and develops inside the mother's womb during pregnancy.                                               |
# | 5   | Elucidate         | To make clear or explain; to clarify or shed light on something                                              | The teacher used diagrams to elucidate the complex scientific concept.                                                 |
# | 6   | Antelope          | A fast-running mammal with long, slender horns, typically found in grassland or savanna habitats               | The graceful antelope leaped over the tall grass, displaying its agility.                                              |
# | 7   | Garnish           | To decorate or embellish, typically with an additional element                                               | The chef garnished the dish with fresh herbs and a drizzle of olive oil.                                               |
# | 8   | Pragmatic         | Dealing with things sensibly and realistically; practical rather than theoretical                            | The team took a pragmatic approach to problem-solving, focusing on solutions that were feasible and effective.         |
# | 9   | Amelioration      | The act of improving or making something better; the process of alleviating or reducing a problem or condition | The government implemented policies for the amelioration of poverty in the country.                                   |
# | 10  | Innocuous         | Not harmful or offensive; unlikely to cause harm or injury                                                    | The spider, although scary-looking, was innocuous and posed no threat to humans.                                       |
# | 11  | Whisker           | Any of the long, projecting hairs growing on the face of certain animals, such as cats or mice                | The cat's whiskers twitched as it carefully observed its surroundings.                                                 |
# | 12  | Nifty             | Stylish, clever, or skillful; pleasingly effective or ingenious                                               | The designer created a nifty solution to maximize storage in the small apartment.                                      |
# | 13  | Legible           | Clear enough to read; easily decipherable                                                                    | The handwriting on the document was neat and legible, making it easy to understand.                                    |
# | 14  | Rectify           | To correct, fix, or remedy an error, mistake, or problem                                                      | The company took immediate action to rectify the billing error and refund the customer.                               |
# | 15  | Inductive         | Involving or based on reasoning from specific facts or examples to a general principle                         | The scientist used inductive reasoning to formulate a hypothesis based on observed patterns.                          |
# | 16  | Ubiquitous        | Present, appearing, or found everywhere; being everywhere at the same time                                   | Smartphones have become ubiquitous in modern society, with people relying on them for various tasks.                   |
# | 17  | Assimilation      | The process of integrating or absorbing information, ideas, or culture into a larger whole                    | The immigrant community went through a process of assimilation, adopting the language and customs of their new country.
#  |
# | 18  | Opacity           | The state of being opaque or not transparent; lacking clarity or translucence                                | The frosted glass had a high level of opacity, preventing a clear view through it.                                     |
# | 19  | Plethora          | A large or excessive amount; an abundance or excess                                                           | The store offered a plethora of options, making it difficult to choose just one item.                                  |
# | 20  | Quintessential    | Representing the most perfect or typical example of something; embodying the essential characteristics         | The little black dress is considered the quintessential fashion staple.                                                |
# | 21  | Agonize           | To suffer intense physical or mental pain; to struggle or worry intensely                                     | The athlete would agonize over every missed opportunity, always striving for perfection.                              |
# | 22  | Fin               | A flattened appendage on a fish, used for stability, maneuvering, or propulsion                               | The shark gracefully moved through the water, its fin cutting through the waves.                                      |
# | 23  | Prevalent         | Widespread or commonly occurring; widely accepted or practiced                                                | In many cultures, the celebration of New Year's Eve is a prevalent tradition.                                          |
# | 24  | Denominator       | The number below the line in a fraction that represents the total number of equal parts                       | In the fraction 3/5, the denominator is 5, indicating five equal parts in total.                                      |
# | 25  | Vet               | To examine, investigate, or evaluate carefully or thoroughly                                                  | Before adopting a pet, it's essential to vet the potential animal to ensure a good fit.                                |
# | 26  | Delimit           | To determine or define the limits or boundaries of something                                                 | The survey aimed to delimit the extent of public support for the new policy.                                           |
# | 27  | Non-exhaustive    | Not comprehensive or complete; not including all possibilities or instances                                   | The list provided is non-exhaustive and may not cover every potential scenario.                                        |
# | 28  | Disseminate       | To spread or distribute widely; to circulate or make known to a large number of people                       | The organization used social media to disseminate information about the upcoming event.                               |
# | 29  | Degenerate        | To decline or deteriorate morally, physically, or in quality                                                  | The neighborhood had degenerated over the years, with abandoned buildings and increased crime rates.                   |
# | 30  | Polynomial        | An algebraic expression consisting of variables and coefficients, involving addition, subtraction, and multiplication | The equation can be solved by finding the roots of the polynomial function.                                           |
# | 31  | Pedagogy          | The method, practice, or profession of teaching; the principles and strategies of education                   | The teacher employed various pedagogical techniques to engage the students in the learning process.                    |
# | 32  | Convolutional     | Relating to or involving convolution; a mathematical operation used in signal processing and deep learning    | Convolutional neural networks are commonly used in image recognition tasks.                                            |
# | 33  | Convolution       | A mathematical operation that combines two functions to produce a third function                             | The convolution of the input signal and the filter produces the output signal in signal processing.                    |
# | 34  | Unwieldy          | Difficult to carry, move, or handle due to size, weight, or complexity                                        | The large and heavy suitcase was unwieldy to transport through the narrow hallway.                                    |
# | 35  | Stipulation       | A condition or requirement that is specified or agreed upon as part of an agreement or contract               | The contract included a stipulation that the work must be completed by a specific deadline.                            |
# | 36  | Caveat            | A warning or cautionary statement; a condition or limitation to be considered                                  | The software comes with a caveat: it may not be compatible with older operating systems.                              |
# | 37  | Nuance            | A subtle difference or distinction in meaning, expression, or sound                                           | The actor's performance was outstanding, capturing the nuanced emotions of the character.                             |
# | 38  | Nuanced           | Having or showing subtle differences in meaning, expression, or sound                                         | The author's writing style is nuanced, allowing for multiple interpretations of the text.                             |
# | 39  | Determinant       | A factor, element, or variable that contributes to the determination or outcome of something                  | Inflation rates and consumer spending are key determinants of economic growth.                                        |
# | 40  | Hedonic           | Relating to or characterized by pleasure or happiness                                                        | The study examined the relationship between hedonic experiences and overall life satisfaction.                        |
# | 41  | Conducive         | Making a certain situation or outcome likely or possible; favorable or helpful                              | A peaceful and supportive learning environment is conducive to student success.                                       |
# | 42  | Inadvertent       | Not intentional; happening by chance or without deliberate effort                                             | She made an inadvertent mistake by sending the email to the wrong recipient.                                          |
# | 43  | Expunge           | To erase, remove, or obliterate completely; to eliminate or destroy                                           | The court ordered the criminal record to be expunged, clearing the person's legal history.                            |
# | 44  | Disparate         | Essentially different or distinct; not comparable or similar                                                 | The two companies had disparate approaches to marketing, resulting in contrasting strategies.                         |
# | 45  | Veracity          | Accuracy or truthfulness; conformity to facts or reality                                                     | The journalist investigated the claims to determine their veracity before publishing the article.                    |
# | 46  | Bursaries         | Scholarships or grants awarded to students to support their education                                         | The university offers bursaries to outstanding students who demonstrate financial need.                               |
# | 47  | Consensus         | General agreement or harmony among a group; a shared opinion or belief                                        | Despite their ubiquitous use, consensus evades the notions of Big Data and Data Science.                               |
# | 48  | Ubiquitous        | Present, appearing, or found everywhere; being everywhere at the same time                                   | Smartphones have become ubiquitous in modern society, with people relying on them for various tasks.                   |
# | 49  | Promontory        | A high point of land or rock projecting into a body of water                                                  | The lighthouse was built on the promontory, providing a clear view of the surrounding landscape.                       |
# | 50  | Perdition         | Utter destruction or ruin; damnation or spiritual loss                                                       | The character's reckless behavior led to his eventual perdition.                                                      |
# | 51  | Namely            | Specifically or particularly; that is to say; indicating something by name                                   | The document listed several countries, namely Germany, France, and Italy.                                              |
# | 52  | Constituent       | A component or part that makes up a whole; a citizen represented by an elected official                       | Each cell is a constituent of the human body.                                                                          |
# | 53  | Inevitably        | Certain to happen; unavoidable or inescapable                                                                | With the storm approaching, canceling the outdoor event was inevitably the right decision.                             |
# | 54  | Invertebrates     | Animals lacking a backbone or spinal column; animals without a vertebral column                              | Insects, spiders, and worms are examples of invertebrates.                                                             |
# | 55  | Acute or chronic toxicity | The ability of a substance to cause harmful effects on living organisms, either in a short-term (acute) or long-term (chronic) exposure | Exposure to the chemical resulted in acute toxicity, causing immediate symptoms.                                       |
# | 56  | Impede            | To obstruct, hinder, or delay the progress or movement of something                                           | The heavy traffic impeded the delivery truck from reaching its destination on time.                                   |
# | 57  | Potent            | Having great power, influence, or effect; strong or effective                                                 | The medicine is potent and can relieve pain within minutes.                                                            |
# | 58  | Deleterious       | Harmful or damaging; detrimental to health or well-being                                                      | Smoking has deleterious effects on lung function and overall health.                                                   |
# | 59  | Volatile          | Evaporating rapidly; easily turning into a vapor or gas; liable to change rapidly or unpredictably             | The volatile liquid evaporated quickly when exposed to heat.                                                           |
# | 60  | Volatilisation    | The process of converting or being converted into a vapor or gas                                              | The volatilization of the substance occurred as it was heated.                                                          |
# | 61  | Synthesize        | To combine or create by synthesis; to form or produce by chemical or biological synthesis                     | The scientist synthesized a new compound by combining various chemical elements.                                       |
# | 62  | Obtrusive         | Noticeable or prominent in an unwelcome or intrusive way                                                      | The large, obtrusive billboard blocked the view of the picturesque landscape.                                          |
# | 63  | Laden             | Heavily loaded or weighed down with a burden or cargo                                                         | The ship sailed slowly, laden with containers filled with goods.                                                       |
# | 64  | Potable           | Safe and suitable for drinking; drinkable                                                                     | The hotel provided complimentary bottles of potable water in each guest room.                                          |
# | 65  | Potable water     | Water that is safe and suitable for drinking                                                                  | Access to clean and potable water is essential for human survival.                                                     |
# | 66  | Adiabatic         | Occurring without the gain or loss of heat                                                                   | The adiabatic process resulted in a change of temperature without any heat exchange with the surroundings.              |
# | 67  | Dispersing agent  | A substance that promotes the even distribution or dispersion of particles or substances                      | The dispersing agent was added to the paint to ensure uniform coverage and prevent clumping.                           |
# | 68  | Sequester         | To isolate, separate, or remove something, especially for a particular purpose or in a controlled manner       | The artwork was sequestered in a temperature-controlled room to preserve its condition.                                |
# | 69  | Subterraneous     | Existing, occurring, or situated underground                                                                 | The subterraneous cave housed ancient rock formations and underground rivers.                                           |
# | 70  | Heterogeneous     | Consisting of diverse or dissimilar elements, parts, or substances                                            | The research team analyzed the heterogeneous data to identify patterns and trends.                                     |
# | 71  | Aperture          | An opening, hole, or gap; a narrow opening that controls the amount of light entering an optical instrument    | The photographer adjusted the aperture to control the depth of field in the image.                                      |
# | 72  | Peripheral Devices | External devices connected to a computer or other electronic device that provide input, output, or storage   | Examples of peripheral devices include keyboards, mice, printers, and external hard drives.                           |
# | 73  | Mitigate          | To make less severe, serious, or painful; to alleviate, reduce, or lessen the impact of something              | The organization implemented measures to mitigate the negative effects of the economic downturn.                      |
# | 74  | Asymptomatic      | Showing no symptoms or signs of a particular disease or condition                                              | Some individuals infected with the virus may be asymptomatic and unknowingly transmit it to others.                    |
# | 75  | Distill           | To purify or extract the essential elements of a substance through a process of heating, vaporization, and condensation | Distilled water is free from impurities and contaminants.                                                              |
# | 76  | Ample             | Plentiful or abundant; enough or more than enough                                                            | The spacious kitchen provided ample room for cooking and entertaining.                                                |
# | 77  | Truncate          | To shorten or cut off abruptly; to reduce the length or duration of something                                  | The speaker's time was truncated to fit within the allotted presentation slot.                                        |
# | 78  | Degradation       | The process of deteriorating or being degraded; a decline in quality, condition, or value                      | Environmental degradation poses a threat to ecosystems and biodiversity.                                             |
# | 79  | Ubiquity          | The state or quality of being present, found, or encountered everywhere                                        | The ubiquity of smartphones has transformed the way people communicate and access information.                       |
# | 80  | Penultimate       | Second to last; immediately preceding the final position or event                                              | The penultimate chapter of the book revealed a major plot twist.                                                       |
# | 81  | Jurisdiction      | The official power to make legal decisions and judgments; the extent of authority or control                   | The case fell under the jurisdiction of the federal court.                                                            |
# | 82  | Deliberate        | Done consciously and intentionally; carefully considered or planned                                             | The team held a deliberate discussion to weigh the pros and cons before making a decision.                            |
# | 83  | Rudimentary       | Basic, fundamental, or undeveloped; relating to the earliest stages of something                               | The child's rudimentary language skills consisted of a few simple words and phrases.                                   |
# | 84  | Amalgamate        | To combine or unite to form a mixture or whole                                                               | The two companies decided to amalgamate their resources and merge into a single entity.                               |
# | 85  | Verbose           | Using or expressed in more words than are needed; wordy or long-winded                                         | The speaker's verbose presentation made it challenging to grasp the main points.                                       |
# | 86  | Monotonous        | Lacking in variety or interest; dull, repetitive, or tedious                                                  | The monotonous hum of the machine put the workers into a trance-like state.                                            |
# | 87  | Intrinsic         | Belonging naturally or inherently; essential or inherent to a thing or situation                               | The artist's intrinsic talent for music was evident from a young age.                                                  |
# | 88  | Precipitate       | To cause to happen suddenly, unexpectedly, or prematurely; to bring about abruptly                             | The controversial decision precipitated a heated debate among the committee members.                                  |
# | 89  | Exacerbate        | To make a problem, situation, or condition worse or more severe                                                | The lack of rainfall exacerbated the drought, leading to water shortages.                                              |
# | 90  | Aesthetic         | Concerned with the appreciation of beauty or the principles of good taste and design                           | The art exhibition showcased a wide range of aesthetic styles and techniques.                                          |
# | 91  | Nebulous          | Vague, unclear, or ill-defined; hazy or lacking distinct shape or form                                         | The concept of love is often nebulous and open to interpretation.                                                      |
# | 92  | Presumptuous      | Failing to observe the limits of what is considered appropriate or polite; overstepping boundaries             | It would be presumptuous to assume that everyone shares the same opinion.                                              |
# | 93  | Connotation       | An idea or feeling that a word invokes in addition to its literal or primary meaning                           | The word "home" has positive connotations of warmth, security, and belonging.                                          |
# | 94  | Ambiguous         | Open to more than one interpretation or having a double meaning; unclear or uncertain                          | The politician's ambiguous statement left the audience unsure of his stance on the issue.                             |
# | 95  | Prolific          | Producing many works, results, or offspring; abundant or fruitful                                              | The prolific author published a new book almost every year.                                                            |
# | 96  | Assemble          | To gather or collect things together; to put together the parts of something                                   | The team will assemble the furniture according to the instructions.                                                   |
# | 97  | Diligent          | Showing care, conscientiousness, and perseverance in one's work or duties                                      | The student was diligent in studying for the exam, spending hours reviewing the material.                             |
# | 98  | Eclectic          | Deriving ideas, style, or taste from a diverse range of sources or influences                                  | The interior design of the house was eclectic, combining elements from various time periods and cultures.             |
# | 99  | Trivial           | Of little value or importance; insignificant or minor                                                         | The error in the report turned out to be trivial and did not affect the overall findings.                             |
# | 100 | Resilient         | Able to withstand or recover quickly from difficult conditions; adaptable and durable                         | The community showed its resilient spirit in rebuilding after the natural disaster.                                    |
