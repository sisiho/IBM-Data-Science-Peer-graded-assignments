# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Siavash Honari**

# %% [markdown]
# Civil Engineer

# %% [markdown]
# *I am interested in data science because it enables me, as a Civil Engineer, to analyze large data sets generated by on-field sensors and transducers. Also, by using machine learning, I would be able to estimate the value of missing parameters which would have been unknown otherwise.*

# %% [markdown]
# ### My code below asks for user's name and stores it as a variable called "name":

# %%
name = input('What is your name? ')
# Out:
# What is your name?  Siavash

# %% [markdown]
# ***
# * This Jupyter Notebook is my peer-graded assignment containing:
#
# 1. five markdown cells
# 1. a simple code collecting the user's name, and
# 1. another markdown having multiple text formats (horizontal rule, bulleted list, numbered list, tables, hyperlinks, highlighting, and strikethrough)
#
# | table | horizontal rule | bullet | numbered list | link | strikethrough |
# | - | - | - | - | - | - | - |
# | - | *** | * | 1. | shift+\ | [Link](www.linkaddress.com) | - |
